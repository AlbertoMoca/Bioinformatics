# %%
import numpy as np

# %%
f = open("rosalind_grph.txt","r")
f1 = f.read()

names_dic = dict()

data = f1.replace('\n','').split('>')[1:]

graph = []

for i in data:
    for j in data:
        if i[:13] != j[:13]:
            if j[13:][:3] == i[13:][-3:]:
                graph.append([i[:13], j[:13]])

# %%
graph
# Out:
# [['Rosalind_2583', 'Rosalind_2168'],
#  ['Rosalind_5271', 'Rosalind_4851'],
#  ['Rosalind_6322', 'Rosalind_9729'],
#  ['Rosalind_6322', 'Rosalind_6219'],
#  ['Rosalind_5783', 'Rosalind_8952'],
#  ['Rosalind_5783', 'Rosalind_5549'],
#  ['Rosalind_5783', 'Rosalind_0558'],
#  ['Rosalind_7794', 'Rosalind_0782'],
#  ['Rosalind_7794', 'Rosalind_4594'],
#  ['Rosalind_7356', 'Rosalind_7796'],
#  ['Rosalind_0782', 'Rosalind_7796'],
#  ['Rosalind_5082', 'Rosalind_8822'],
#  ['Rosalind_3081', 'Rosalind_0524'],
#  ['Rosalind_3081', 'Rosalind_7358'],
#  ['Rosalind_1218', 'Rosalind_8484'],
#  ['Rosalind_9241', 'Rosalind_8822'],
#  ['Rosalind_5060', 'Rosalind_7784'],
#  ['Rosalind_5060', 'Rosalind_0488'],
#  ['Rosalind_8190', 'Rosalind_5740'],
#  ['Rosalind_8190', 'Rosalind_9797'],
#  ['Rosalind_8190', 'Rosalind_3755'],
#  ['Rosalind_7227', 'Rosalind_1897'],
#  ['Rosalind_4594', 'Rosalind_4283'],
#  ['Rosalind_9578', 'Rosalind_7784'],
#  ['Rosalind_9578', 'Rosalind_0488'],
# ...

# %%
for i in graph:
    print(i[0]+" "+i[1])
# Out:
# Rosalind_2583 Rosalind_2168
# Rosalind_5271 Rosalind_4851
# Rosalind_6322 Rosalind_9729
# Rosalind_6322 Rosalind_6219
# Rosalind_5783 Rosalind_8952
# Rosalind_5783 Rosalind_5549
# Rosalind_5783 Rosalind_0558
# Rosalind_7794 Rosalind_0782
# Rosalind_7794 Rosalind_4594
# Rosalind_7356 Rosalind_7796
# Rosalind_0782 Rosalind_7796
# Rosalind_5082 Rosalind_8822
# Rosalind_3081 Rosalind_0524
# Rosalind_3081 Rosalind_7358
# Rosalind_1218 Rosalind_8484
# Rosalind_9241 Rosalind_8822
# Rosalind_5060 Rosalind_7784
# Rosalind_5060 Rosalind_0488
# Rosalind_8190 Rosalind_5740
# Rosalind_8190 Rosalind_9797
# Rosalind_8190 Rosalind_3755
# Rosalind_7227 Rosalind_1897
# Rosalind_4594 Rosalind_4283
# Rosalind_9578 Rosalind_7784
# Rosalind_9578 Rosalind_0488
# Rosalind_0524 Rosalind_0527
# Rosalind_8756 Rosalind_4818
# Rosalind_8756 Rosalind_0276
# Rosalind_8756 Rosalind_1566
# Rosalind_4912 Rosalind_2583
# Rosalind_4912 Rosalind_5060
# Rosalind_4912 Rosalind_1780
# Rosalind_4283 Rosalind_0527
# ...
